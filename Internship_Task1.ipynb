# %% [markdown]
# Required Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Dataset

# %%
#Load the Iris Dataset
df = sns.load_dataset('iris')

# %% [markdown]
# Simple Operations to describe Dataset

# %%
print("The Shape of Dataset:", df.shape)
print("Coulmn Names of Dataset:", df.columns.tolist())
print("Few rows of Dataset",df.head())
print("\nInfo Of Dataset: ", df.info())
print("\n\nSummary of Dataset: ", df.describe())
# Out:
# The Shape of Dataset: (150, 5)
# Coulmn Names of Dataset: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# Few rows of Dataset    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# ...

# %% [markdown]
# Visualization with scatter plot

# %%
#A. Scatter Plot – Relationships Between Features
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue='species')
plt.title('Petal length vs Petal width by species')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %% [markdown]
# Visualization with Histogram

# %%
#B. Histograms – Value Distributions

df.hist(bins=15, figsize=(10,8), edgecolor='black')
plt.suptitle("Feature Distribution", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Visualization with Box Plot

# %%
#Box Plots – Detecting Outliers
plt.figure(figsize = (12,8))
for i,column in enumerate(df.columns[:-1], 1):
  plt.subplot(2,2,i)
  sns.boxplot(x = 'species', y = column, data = df)
  plt.title(f'Box plot of {column} by Species')
plt.tight_layout()
plt.show()
